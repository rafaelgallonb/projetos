# %% [markdown]
# # <font color='blue'>Formação Analista de Dados [FADA] - Data Science Academy</font>
# # <font color='blue'>Análise de Dados com Linguagem Python</font>
#
# ## <font color='blue'>Projeto 10 - Design e Construção de 50 Visualizações</font>
# ## <font color='blue'>Visualizações de 01 a 08</font>

# %% [markdown]
# ### Definição do Problema e Fonte de Dados
#
# Neste mini-projeto o objetivo será compreender a relação entre as variáveis de operação de um restaurante.

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Imports
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dados = pd.read_csv("dados/dataset1.csv")

# %%
dados.shape
# Out:
# (244, 7)

# %%
dados.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
dados.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
dados.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
dados.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# > ### Dataviz 01 - Scatter Plot com a relação entre duas variáveis

# %%
# Dataviz 01
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", data = dados)

# %% [markdown]
# > ### Dataviz 02 - Scatter Plot com a relação entre duas variáveis e os pontos coloridos pelas categorias de uma terceira variável

# %%
# Dataviz 02
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", data = dados)

# %% [markdown]
# > ### Dataviz 03 - Scatter Plot com a relação entre duas variáveis, os pontos coloridos pelas categorias de uma terceira variável e diferentes símbolos por categoria (gráfico mostrando informação de 3 variáveis diferentes)

# %%
# Dataviz 03
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", style = "smoker", data = dados)

# %% [markdown]
# > ### Dataviz 04 - Scatter Plot com a relação entre duas variáveis, os pontos coloridos pelas categorias de uma terceira variável, diferentes símbolos por categoria e por variável (gráfico mostrando informação de 4 variáveis diferentes)

# %%
# Dataviz 04
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", style = "time", data = dados)

# %% [markdown]
# > ### Dataviz 05 - Scatter Plot com a relação entre duas variáveis e os pontos coloridos pelas categorias de uma terceira variável (gráfico mostrando informação de 3 variáveis diferentes)

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Dataviz 05
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", hue = "size", data = dados)

# %% [markdown]
# > ### Dataviz 06 - Scatter Plot com a relação entre duas variáveis e os pontos coloridos pelas categorias de uma terceira variável, com ajuste na escala dos símbolos (gráfico mostrando informação de 3 variáveis diferentes)

# %%
# Dataviz 06
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", hue = "size", palette = "ch:r=-.5,l=.75", data = dados)

# %% [markdown]
# > ### Dataviz 07 - Scatter Plot com a relação entre duas variáveis e os pontos com tamanhos definidos pelas categorias de uma terceira variável (gráfico mostrando informação de 3 variáveis diferentes)

# %%
# Dataviz 07
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", size = "size", data = dados)

# %% [markdown]
# > ### Dataviz 08 - Scatter Plot com a relação entre duas variáveis e os pontos com tamanhos definidos pelas categorias de uma terceira variável, com ajuste da escala dos símbolos (gráfico mostrando informação de 3 variáveis diferentes)

# %%
# Dataviz 08
plt.figure(figsize = (20,8))
sns.relplot(x = "total_bill", y = "tip", size = "size", sizes = (15, 200), data = dados)

# %% [markdown]
# # Fim
